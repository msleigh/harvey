# %% [markdown]
# # Verification of `harvey`

# %% [markdown]
# Plots `harvey` numerical solution (dashed red line) against analytic solution (blue line) for test problems.

# %% [markdown]
# ## Planar geometry tests

# %% [markdown]
# ### Finite domain tests

# %% [markdown]
# #### Homogeneous tests

# %% [markdown]
# ##### Test 1
# - Explicit scheme $\left(\alpha=0\right)$
# - Constant boundary conditions $\left(\phi(0,t)=\phi(1,t)=0\right)$
# - Sinusoidal initial condition
# <img src="build/QA/test1.png" width="750">

# %% [markdown]
# ##### Test 2
# - Laasonen $\left(\alpha = 1\right)$
# - Constant bundary conditions $\left(\phi(0,t)=\phi(1,t)=0\right)$
# - Sinusoidal initial condition
# <img src="build/QA/test2.png" width="750">

# %% [markdown]
# ##### Test 15
# - Crank-Nicholson ($\alpha = 0.5$)
# - $\phi(0,t)=0$
# - $\phi'(0.5,t)=0$
# - Sinusoidal initial condition
# <img src="build/QA/test15.png" width="500">

# %% [markdown]
# ##### Test 17
# - Crank-Nicholson ($\alpha = 0.5$)
# - $\phi'(0,t)=0$
# - $\phi(0.5,t)=0$
# - Sinusoidal initial condition
# <img src="build/QA/test17.png" width="500">

# %% [markdown]
# ##### Test 3
# - Crank-Nicholson ($\alpha = 0.5$)
# - $\phi(0,t)=0$
# - $\phi(1,t)=0$
# - Constant initial condition
# <img src="build/QA/test3.png" width="750">

# %% [markdown]
# ##### Test 4
# - Explicit ($\alpha$=0.0)
# - $\phi(0,t) = 0$
# - $\phi(\pi,t) = 0$
# - Chevron initial condition
# <img src="build/QA/test4.png" width="750">

# %% [markdown]
# ### Test 5
# - Explicit ($\alpha=0$)
# - $\phi(0,t) = 100$
# - $\phi'(1,t) = 0$
# <img src="build/QA/test5.png" width="750">

# %% [markdown]
# ### Test 6
# <img src="build/QA/test6.png" width="500">

# %% [markdown]
# ### Test 7
# - Explicit ($\alpha=0$)
# - $\phi(0,t) = 0$
# - $\phi(\pi,t) = 0$
# - Constant initial condition
# <img src="build/QA/test7.png" width="500">

# %% [markdown]
# ### Test 8
# - Explicit ($\alpha = 0$)
# - $\phi(0,t) = 1$
# - $\phi(\pi,t) = 0$
# - Zero initial condition
# <img src="build/QA/test8.png" width="750">

# %% [markdown]
# ### Test 9
# - Crank-Nicholson ($\alpha = 0.5$)
# - $\phi(0,t) = 1$
# - $\phi(\pi,t) = 0$
# - Zero initial condition
# <img src="build/QA/test9.png" width="750">

# %% [markdown]
# ### Test 10
# - Explicit ($\alpha=0$)
# - $\phi(0,t) = 100$
# - $\phi(1,t) = 0$
# <img src="build/QA/test10.png" width="750">

# %% [markdown]
# ### Test 11
# - Crank-Nicholson ($\alpha = 0.5$)
# - $\phi(0,t)=0$
# - $\phi(\pi,t)=1$
# - Constant initial condition
# <img src="build/QA/test11.png" width="500">

# %% [markdown]
# ### Test 12
# - Explicit ($\alpha = 0$)
# - $\phi(0,t)=0$
# - $\phi(\pi,t)=1$
# - Constant initial condition
# <img src="build/QA/test12.png" width="500">

# %% [markdown]
# ### Test 13
# - Explicit ($\alpha = 0$)
# - $\phi(0,t)=0$
# - $\phi'(\pi,t)=1$
# <img src="build/QA/test13.png" width="500">

# %% [markdown]
# ### Test 14
# - Crank-Nicholson ($\alpha = 0.5$)
# - $\phi(0,t)=0$
# - $\phi'(\pi,t)=1$
# <img src="build/QA/test14.png" width="500">

# %% [markdown]
# ### Test 16
# - Explicit ($\alpha = 0$)
# - $\phi'(0,t)=0$
# - $\phi(1,t)=100$
# <img src="build/QA/test16.png" width="500">

# %% [markdown]
# ### Test 18
# - Explicit ($\alpha = 0$)
# - $\phi(0,t)=0$
# - $\phi(\pi,t)=0$
# - Chevron initial condition
# <img src="build/QA/test18.png" width="500">
